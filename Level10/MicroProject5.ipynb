# %%
import pandas as pd, numpy as np, seaborn as sns, matplotlib.pyplot as plt
from scipy import stats

df = pd.read_csv('super stores.csv', encoding='ISO-8859-1')
df['Sales'] = pd.to_numeric(df['Sales'], errors='coerce')
df = df.dropna(subset=['Sales'])
df['z_score'] = stats.zscore(df['Sales'])
outliers = df[(df['z_score'] > 3) | (df['z_score'] < -3)]
print(outliers[['Sales', 'z_score']])

plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Sales'])
plt.title('Boxplot of Sales')
plt.xlabel('Sales')
plt.show()
# Out:
#          Sales    z_score
# 27    3083.430   4.552458
# 165   8159.952  12.653896
# 251   3347.370   4.973671
# 262   3059.982   4.515038
# 263   2519.958   3.653234
# ...        ...        ...
# 9639  4297.644   6.490178
# 9649  3406.664   5.068296
# 9660  3023.928   4.457501
# 9741  4404.900   6.661344
# 9774  2177.584   3.106851
#
# [123 rows x 2 columns]
