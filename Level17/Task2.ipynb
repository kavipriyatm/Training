# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import load_digits
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
digits = load_digits()
X = pd.DataFrame(digits.data)
y = pd.Series(digits.target)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=4)
X_pca = pca.fit_transform(X_scaled)
explained_variance = pca.explained_variance_ratio_.cumsum()

# %%
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(X_pca[:, 0], X_pca[:, 1], X_pca[:, 2], c=y, cmap='tab10', s=25)
legend = ax.legend(*scatter.legend_elements(), title="Digits", loc="upper right")
ax.add_artist(legend)
ax.set_title("3D PCA Scatter Plot of Digits Dataset")
plt.show()

print("Cumulative Explained Variance:", explained_variance)
# Out:
# Cumulative Explained Variance: [0.12033916 0.21594971 0.30039385 0.36537793]
